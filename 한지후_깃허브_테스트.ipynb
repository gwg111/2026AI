# %% [markdown]
# <a href="https://colab.research.google.com/github/gwg111/2026AI/blob/main/%ED%95%9C%EC%A7%80%ED%9B%84_%EA%B9%83%ED%97%88%EB%B8%8C_%ED%85%8C%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Github Test')

# %%
# !git clone https://github.com/gardenchoi20/2026data
# Out:
# Cloning into '2026data'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 5.36 KiB | 5.36 MiB/s, done.

# %%
ls
# Out:
# 2026data/  sample_data/

# %%
cd 2026data
# Out:
# /content/2026data

# %%
ls
# Out:
# heart_test.csv  heart_train1.csv  README.md
